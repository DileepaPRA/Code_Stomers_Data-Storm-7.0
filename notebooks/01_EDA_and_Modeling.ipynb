# %% [markdown]
# # DataStorm 7.0 - Exploratory Data Analysis & Modeling
#
# This notebook provides an interactive environment to explore the data and evaluate the latent potential models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# Add src to path
sys.path.append(os.path.abspath('../src'))
from config import *

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Load Data

# %%
# Load model ready dataset
df = pd.read_csv(os.path.join(GOLD_DIR, MODEL_READY_FILE))
print(f"Loaded {len(df)} outlets with {df.shape[1]} features.")
df.head()

# %% [markdown]
# ## 2. Load Predictions

# %%
preds = pd.read_csv(os.path.join(OUTPUT_DIR, PREDICTIONS_FILE))
analysis = pd.read_csv(os.path.join(GOLD_DIR, POTENTIAL_ANALYSIS))

plt.figure(figsize=(10, 6))
sns.histplot(preds['Maximum_Monthly_Liters'], bins=50, kde=True)
plt.title('Distribution of Predicted Maximum Monthly Volume')
plt.xlabel('Liters')
plt.show()
